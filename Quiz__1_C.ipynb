# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
from IPython.display import Image

# %%
#mount google drive to colab environment
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#path of example directory 
path = "/content/drive/MyDrive/DLIVACV_workshop/day1/Assignment/"

# %%
# Reading an image using OpenCV
# OpenCV reads images by default in BGR format
image = cv2.imread('/content/gdrive/MyDrive/DLIVACV_workshop/day1/Assignment/OIP (1).jpeg')

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
def displayImage(image):
    if len(image.shape)==3:
        color_coverted = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        plt.imshow(color_coverted)
        plt.show()
        
    else:
        plt.imshow(image, cmap="gray")
        plt.show()

# %%
blur = cv2.GaussianBlur(gray, (11, 11), 0)
canny = cv2.Canny(blur, 30, 150, 3)
dilated = cv2.dilate(canny, (1, 1), iterations=0)

# %%
displayImage(image)

# %%
(cnt, hierarchy) = cv2.findContours(
    dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0, 255, 0), 2)
# Out:
# array([[[236, 237, 239],
#         [236, 237, 239],
#         [236, 237, 239],
#         ...,
#         [233, 234, 236],
#         [233, 234, 236],
#         [233, 234, 236]],
#
#        [[236, 237, 239],
#         [236, 237, 239],
#         [236, 237, 239],
#         ...,
#         [233, 234, 236],
#         [233, 234, 236],
#         [233, 234, 236]],
#
#        [[236, 237, 239],
#         [236, 237, 239],
#         [236, 237, 239],
#         ...,
#         [234, 235, 237],
#         [234, 235, 237],
#         [234, 235, 237]],
#
#        ...,
#
#        [[223, 224, 226],
#         [223, 224, 226],
#         [223, 224, 226],
#         ...,
#         [219, 225, 225],
#         [219, 225, 225],
#         [219, 225, 225]],
#
#        [[223, 224, 226],
#         [223, 224, 226],
#         [223, 224, 226],
#         ...,
#         [219, 225, 225],
#         [219, 225, 225],
#         [219, 225, 225]],
#
#        [[223, 224, 226],
#         [223, 224, 226],
#         [223, 224, 226],
# ...

# %%
print("Number of coins in the image : ", len(cnt))
# Out:
# Number of coins in the image :  2
